# %%
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Q1** Please use Pandas to read olympic_medals.csv and use parallel_categories function from plotly.express to visualize proportions of medal type for each gender from since year 2000. Please see the example in the Python notebook we walked through in the class.

# %%
#please use this cell to read and select your data
df = pd.read_csv("/content/drive/MyDrive/DATA/olympic_medals.csv")
df
# Out:
#      Gender              Event Location  Year Medal                   Name  \
# 0         M         10000M Men      Rio  2016     G          Mohamed FARAH
# 1         M         10000M Men      Rio  2016     S  Paul Kipngetich TANUI
# 2         M         10000M Men      Rio  2016     B           Tamirat TOLA
# 3         M         10000M Men  Beijing  2008     G        Kenenisa BEKELE
# 4         M         10000M Men  Beijing  2008     S         Sileshi SIHINE
# ...     ...                ...      ...   ...   ...                    ...
# 2389      W  Triple Jump Women   Athens  2004     S      Hrysopiyi DEVETZI
# 2390      W  Triple Jump Women   Athens  2004     B       Tatyana LEBEDEVA
# 2391      W  Triple Jump Women  Atlanta  1996     G         Inessa KRAVETS
# 2392      W  Triple Jump Women  Atlanta  1996     S        Inna LASOVSKAYA
# 2393      W  Triple Jump Women  Atlanta  1996     B       Sarka KASPARKOVA
#
#      Nationality    Result
# 0            GBR  25:05.17
# 1            KEN  27:05.64
# 2            ETH  27:06.26
# 3            ETH  27:01.17
# 4            ETH  27:02.77
# ...          ...       ...
# 2389         GRE     15.25
# 2390         RUS     15.14
# 2391         UKR     15.33
# 2392         RUS     14.98
# 2393         CZE     14.98
#
# [2394 rows x 8 columns]

# %%
# !pip install squarify

import plotly.express as px
df = df[(df['Medal']!='?')]
plt.style.use('ggplot')  
px.parallel_categories(df[['Gender', 'Medal', 'Year']])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2877afdf-2dd9-48f8-a391-c681993fd5ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2877afdf-2dd9-48f8-a391-c681993fd5ef")) {                    Plotly.newPlot(                        "2877afdf-2dd9-48f8-a391-c681993fd5ef",                        [{"dimensions":[{"label":"Gender","values":["M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M"," ...

# %%
#Please use this cell to create your your figure. Please use Year column to color your graph.

px.parallel_categories(df, dimensions=['Gender', 'Medal', 'Year'], color="Year", color_continuous_scale=px.colors.sequential.Inferno)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="becc54dc-8c98-4b49-9387-f35706d6a242" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("becc54dc-8c98-4b49-9387-f35706d6a242")) {                    Plotly.newPlot(                        "becc54dc-8c98-4b49-9387-f35706d6a242",                        [{"dimensions":[{"label":"Gender","values":["M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M"," ...

# %% [markdown]
# **Q2** Please inspect the code below and observe how values are plotted by running it. Then, read the 2016elections.csv from the DATA folder and select rows for AR, MI, CA, and WI. Then, utilize stacked bar plot, to stack vote percentages for Trump, Clinton, Johnson, and Others. Please see 'pct_clinton',	'pct_trump',	'pct_johnson',	'pct_other' columns. Make sure that your x tick labels are those four states above.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
# create DataFrame
df = pd.DataFrame({'High Temp': [28, 30, 34, 38, 45, 42,
                                 38, 35, 32, 28, 25, 21],
                   'Low Temp': [22, 26, 30, 32, 41, 38,
                                32, 31, 28, 22, 15, 15],
                   'Avg Temp': [25, 28, 32, 35, 43, 40,
                                35, 33, 30, 25, 20, 18]},
                  index=['Jan', 'Feb', 'Mar', 'Apr', 'May',
                         'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
                         'Nov', 'Dec'])
 
 
# create stacked bar chart for monthly temperatures
df.plot(kind='bar', stacked=True, color=['red', 'skyblue', 'green'])
 
# labels for x & y axis
plt.xlabel('Months')
plt.ylabel('Temp ranges in Degree Celsius')
 
# title of plot
plt.title('Monthly Temperatures in a year')
# Out:
# Text(0.5, 1.0, 'Monthly Temperatures in a year')

# %%
#You can use this cell to write your code. It is doable at most 4 lines of code. 
elections = pd.read_csv("/content/drive/MyDrive/DATA/2016elections.csv")
elections
# Out:
#                    state  st  fips  total_vote  vote_margin   winner  \
# 0                Alabama  AL     1     2123372       588708    Trump
# 1                 Alaska  AK     2      318608        46933    Trump
# 2                Arizona  AZ     4     2604657        91234    Trump
# 3               Arkansas  AR     5     1130635       304378    Trump
# 4             California  CA     6    14237893      4269978  Clinton
# 5               Colorado  CO     8     2780247       136386  Clinton
# 6            Connecticut  CT     9     1644920       224357  Clinton
# 7               Delaware  DE    10      443814        50476  Clinton
# 8   District of Columbia  DC    11      311268       270107  Clinton
# 9                Florida  FL    12     9502747       112911    Trump
# 10               Georgia  GA    13     4141447       211141    Trump
# 11                Hawaii  HI    15      428937       138044  Clinton
# 12                 Idaho  ID    16      690433       219290    Trump
# 13              Illinois  IL    17     5594825       944714  Clinton
# 14               Indiana  IN    18     2757965       524160    Trump
# 15                  Iowa  IA    19     1566031       147314    Trump
# 16                Kansas  KS    20     1194755       244013    Trump
# 17              Kentucky  KY    21     1924150       574117    Trump
# 18             Louisiana  LA    22     2029032       398484    Trump
# 19                 Maine  ME    23      747927        22142  Clinton
# 20              Maryland  MD    24     2781446       734759  Clinton
# 21         Massachusetts  MA    25     3325046       904303  Clinton
# 22              Michigan  MI    26     4824542        10704    Trump
# 23             Minnesota  MN    27     2945233        44593  Clinton
# 24           Mississippi  MS    28     1211088       215583    Trump
# 25              Missouri  MO    29     2828266       523443    Trump
# 26               Montana  MT    30      501822       101531    Trump
# 27              Nebraska  NE    31      844227       211467    Trump
# 28                Nevada  NV    32     1125385        27202  Clinton
# 29         New Hampshire  NH    33      744296         2736  Clinton
# 30            New Jersey  NJ    34     3906723       546345  Clinton
# 31            New Mexico  NM    35      798319        65567  Clinton
# 32              New York  NY    36     7721795      1736585  Clinton
# 33        North Carolina  NC    37     4741564       173315    Trump
# 34          North Dakota  ND    38      344360       123036    Trump
# 35                  Ohio  OH    39     5536547       446837    Trump
# 36              Oklahoma  OK    40     1452992       528761    Trump
# 37                Oregon  OR    41     2001336       219703  Clinton
# 38          Pennsylvania  PA    42     6166729        44292    Trump
# 39          Rhode Island  RI    44      464144        71982  Clinton
# 40        South Carolina  SC    45     2103027       300016    Trump
# 41          South Dakota  SD    46      370093       110263    Trump
# 42             Tennessee  TN    47     2508027       652230    Trump
# 43                 Texas  TX    48     8993166       807179    Trump
# 44                  Utah  UT    49     1143601       204555    Trump
# 45               Vermont  VT    50      315067        83204  Clinton
# 46              Virginia  VA    51     3982752       212030  Clinton
# 47            Washington  WA    53     3316996       520971  Clinton
# 48         West Virginia  WV    54      721233       300577    Trump
# 49             Wisconsin  WI    55     2976150        22748    Trump
# 50               Wyoming  WY    56      255849       118446    Trump
#
#          party  pct_margin  r_points  d_points  ...  pct_johnson  pct_other  \
# 0   Republican      0.2773     27.72    -27.72  ...         2.09       1.46
# 1   Republican      0.1473     14.73    -14.73  ...         5.88       6.29
# 2   Republican      0.0350      3.50     -3.50  ...         4.08       3.25
# 3   Republican      0.2692     26.92    -26.92  ...         2.64       3.13
# 4   Democratic      0.2999    -29.99     29.99  ...         3.36       3.66
# 5   Democratic      0.0491     -4.91      4.91  ...         5.18       3.41
# 6   Democratic      0.1364    -13.64     13.64  ...         2.96       1.55
# 7   Democratic      0.1137    -11.38     11.38  ...         3.33       1.88
# 8   Democratic      0.8678    -86.77     86.77  ...         1.58       3.47
# 9   Republican      0.0119      1.19     -1.19  ...         2.18       1.82
# 10  Republican      0.0510      5.09     -5.09  ...         3.03       1.18
# 11  Democratic      0.3218    -32.18     32.18  ...         3.72       4.02
# 12  Republican      0.3176     31.77    -31.77  ...         4.10       9.17
# 13  Democratic      0.1689    -16.88     16.88  ...         3.75       2.65
# 14  Republican      0.1901     19.01    -19.01  ...         4.86       1.22
# 15  Republican      0.0941      9.41     -9.41  ...         3.78       3.33
# 16  Republican      0.2042     20.42    -20.42  ...         4.64       3.46
# 17  Republican      0.2984     29.84    -29.84  ...         2.79       2.00
# 18  Republican      0.1964     19.64    -19.64  ...         1.87       1.59
# 19  Democratic      0.0296     -2.96      2.96  ...         5.09       2.21
# 20  Democratic      0.2642    -26.42     26.42  ...         2.86       2.90
# 21  Democratic      0.2720    -27.20     27.20  ...         4.15       3.04
# 22  Republican      0.0022      0.22     -0.22  ...         3.57       2.16
# 23  Democratic      0.0151     -1.51      1.51  ...         3.84       4.79
# 24  Republican      0.1780     17.80    -17.80  ...         1.19       0.89
# 25  Republican      0.1851     18.51    -18.51  ...         3.44       2.31
# 26  Republican      0.2023     20.24    -20.24  ...         5.59       3.35
# 27  Republican      0.2505     25.05    -25.05  ...         4.61       2.94
# 28  Democratic      0.0242     -2.42      2.42  ...         3.32       3.26
# 29  Democratic      0.0037     -0.37      0.37  ...         4.14       2.58
# 30  Democratic      0.1398    -13.99     13.99  ...         1.86       2.15
# 31  Democratic      0.0821     -8.22      8.22  ...         9.34       2.36
# 32  Democratic      0.2249    -22.49     22.49  ...         2.29       2.20
# 33  Republican      0.0366      3.66     -3.66  ...         2.74       1.25
# 34  Republican      0.3573     35.73    -35.73  ...         6.22       3.59
# 35  Republican      0.0807      8.07     -8.07  ...         3.15       2.29
# 36  Republican      0.3639     36.39    -36.39  ...         5.75       0.00
# 37  Democratic      0.1098    -10.98     10.98  ...         4.71       6.13
# 38  Republican      0.0072      0.71     -0.71  ...         2.38       1.99
# 39  Democratic      0.1551    -15.51     15.51  ...         3.18       3.52
# 40  Republican      0.1427     14.27    -14.27  ...         2.34       2.05
# 41  Republican      0.2979     29.79    -29.79  ...         5.63       1.10
# 42  Republican      0.2601     26.00    -26.00  ...         2.81       1.75
# 43  Republican      0.0898      8.98     -8.98  ...         3.15       1.63
# 44  Republican      0.1789     17.88    -17.88  ...         3.46      24.32
# 45  Democratic      0.2641    -26.41     26.41  ...         3.20       9.85
# 46  Democratic      0.0532     -5.32      5.32  ...         2.97       2.85
# 47  Democratic      0.1571    -15.71     15.71  ...         4.85       5.78
# 48  Republican      0.4168     41.67    -41.67  ...         3.19       2.78
# 49  Republican      0.0076      0.77     -0.77  ...         3.58       2.74
# 50  Republican      0.4630     46.29    -46.29  ...         5.19       4.76
#
#     clinton_vote  trump_vote  johnson_vote  other_vote  ev_dem  ev_rep  \
# 0         729547     1318255         44467       31103       0       9
# 1         116454      163387         18725       20042       0       3
# 2        1161167     1252401        106327       84762       0      11
# 3         380494      684872         29829       35440       0       6
# 4        8753792     4483814        478500      521787      55       0
# 5        1338870     1202484        144121       94772       9       0
# 6         897572      673215         48676       25457       7       0
# 7         235603      185127         14757        8327       3       0
# 8         282830       12723          4906       10809       3       0
# 9        4504975     4617886        207043      172843       0      29
# 10       1877963     2089104        125306       49074       0      16
# 11        266891      128847         15954       17245       3       0
# 12        189765      409055         28331       63282       0       4
# 13       3090729     2146015        209596      148485      20       0
# 14       1033126     1557286        133993       33560       0      11
# 15        653669      800983         59186       52193       0       6
# 16        427005      671018         55406       41326       0       6
# 17        628854     1202971         53752       38573       0       8
# 18        780154     1178638         37978       32262       0       8
# 19        357735      335593         38105       16494       3       1
# 20       1677928      943169         79605       80744      10       0
# 21       1995196     1090893        138018      100939      11       0
# 22       2268839     2279543        172136      104024       0      16
# 23       1367825     1323232        112984      141192      10       0
# 24        485131      700714         14435       10808       0       6
# 25       1071068     1594511         97359       65328       0      10
# 26        177709      279240         28037       16836       0       3
# 27        284494      495961         38946       24826       0       5
# 28        539260      512058         37384       36683       6       0
# 29        348526      345790         30777       19203       4       0
# 30       2148278     1601933         72477       84035      14       0
# 31        385234      319667         74541       18877       5       0
# 32       4556142     2819557        176600      169496      29       0
# 33       2189316     2362631        130126       59491       0      15
# 34         93758      216794         21434       12374       0       3
# 35       2394169     2841006        174498      126874       0      18
# 36        420375      949136         83481           0       0       7
# 37       1002106      782403         94231      122596       7       0
# 38       2926441     2970733        146715      122840       0      20
# 39        252525      180543         14746       16330       4       0
# 40        855373     1155389         49204       43061       0       9
# 41        117458      227721         20850        4064       0       3
# 42        870695     1522925         70397       44010       0      11
# 43       3877868     4685047        283492      146759       0      36
# 44        310676      515231         39608      278086       0       6
# 45        178573       95369         10078       31047       3       0
# 46       1981473     1769443        118274      113562      13       0
# 47       1742718     1221747        160879      191652       8       0
# 48        188794      489371         23004       20064       0       5
# 49       1382536     1405284        106674       81656       0      10
# 50         55973      174419         13287       12170       0       3
#
#     ev_oth     census
# 0        0      South
# 1        0       West
# 2        0       West
# 3        0      South
# 4        0       West
# 5        0       West
# 6        0  Northeast
# 7        0      South
# 8        0      South
# 9        0      South
# 10       0      South
# 11       1       West
# 12       0       West
# 13       0    Midwest
# 14       0    Midwest
# 15       0    Midwest
# 16       0    Midwest
# 17       0      South
# 18       0      South
# 19       0  Northeast
# 20       0      South
# 21       0  Northeast
# 22       0    Midwest
# 23       0    Midwest
# 24       0      South
# 25       0    Midwest
# 26       0       West
# 27       0    Midwest
# 28       0       West
# 29       0  Northeast
# 30       0  Northeast
# 31       0       West
# 32       0  Northeast
# 33       0      South
# 34       0    Midwest
# 35       0    Midwest
# 36       0      South
# 37       0       West
# 38       0  Northeast
# 39       0  Northeast
# 40       0      South
# 41       0    Midwest
# 42       0      South
# 43       2      South
# 44       0       West
# 45       0  Northeast
# 46       0      South
# 47       4       West
# 48       0      South
# 49       0    Midwest
# 50       0       West
#
# [51 rows x 22 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
# create DataFrame
df = pd.DataFrame({'Pct_Trump': [60.57, 47.25, 31.49, 47.22 ],
                   'Pct_Clinton': [33.65, 47.03, 61.48, 46.45],
                   'Pct_Johnson': [2.64, 3.57, 3.36, 3.58],
                   'Pct_Other' : [3.13, 2.16, 3.66, 2.74]},

                  index=['AR', 'MI', 'CA', 'WI'])
 
 
# create stacked bar chart for monthly temperatures
df.plot(kind='bar', stacked=True, color=['red', 'skyblue', 'green'])
 
# labels for x & y axis
plt.xlabel('States')
plt.ylabel('Candidate Votes ')
 
# title of plot
plt.title('Candidate Votes by State')
# Out:
# Text(0.5, 1.0, 'Candidate Votes by State')
